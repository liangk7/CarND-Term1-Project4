# %% [markdown]
# ## Advanced Lane Finding Project
#
# The goals / steps of this project are the following:
#
# * Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# * Apply a distortion correction to raw images.
# * Use color transforms, gradients, etc., to create a thresholded binary image.
# * Apply a perspective transform to rectify binary image ("birds-eye view").
# * Detect lane pixels and fit to find the lane boundary.
# * Determine the curvature of the lane and vehicle position with respect to center.
# * Warp the detected lane boundaries back onto the original image.
# * Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.
#
# ---

# %% [markdown]
# ### Imports

# %%
# Libraries
import cv2
import glob
import imageio
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pickle
import sklearn

from ipywidgets import interact, interactive, fixed
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# Other
np.set_printoptions(threshold=np.nan)
# %matplotlib inline

# %% [markdown]
# ### Paths

# %%
# Camera Calibration
path_calImages = 'camera_cal/'

# Images
path_imgIn = 'test_images/'
path_imgOut = 'output_images/'

# Videos
path_vidIn = 'test_videos/'
path_vidOut = 'output_videos/'

# %% [markdown]
# ### Parameters

# %%
# Source and destination points

# Pixel distance (meters)

# %% [markdown]
# ### Classes

# %%
# Frame class stores image processing features
class Frame():
    def __init__(self):
        # Image Depictions
        self.orig = None # raw image
        self.undst = None # camera calibrated original image
        self.warp = None # aerial view of undistorted image
        self.gray = None # grayscale of warped image
        self.color_binary = None # binary grayscale using color space thresholds
        self.sobel_binary = None # binary grayscale using sobel thresholds
        self.combined_binary = None # binary combination of color and sobel binaries
        self.detected_lines = None # colormap of detected lanes
        self.final = None # depiction of lane mask on undistorted image
        self.collage = None # collage of important image steps
        
        # Image Properties
        self.M = None
        self.Minv = None
        self.objpts = None
        self.imgpts = None
        self.hist = None
        
        # Lane Lines
        self.lineLeft = Line()
        self.lineRight = Line()
        
        # Lane Properties
        self.laneRad = None
        self.lanePos = None
        
    def reset(self):
        # Image Depictions
        self.orig = None # raw image
        self.undst = None # camera calibrated original image
        self.warp = None # aerial view of undistorted image
        self.gray = None # grayscale of warped image
        self.color_binary = None # binary grayscale using color space thresholds
        self.sobel_binary = None # binary grayscale using sobel thresholds
        self.combined_binary = None # binary combination of color and sobel binaries
        self.detected_lines = None # colormap of detected lanes
        self.final = None # depiction of lane mask on undistorted image
        self.collage = None # collage of all image steps
        
        # Lane Lines
        self.lineLeft = Line()
        self.lineRight = Line()
        
        # Lane Properties
        self.laneRad = None
        self.lanePos = None
        
# Line class stores line calculation features
class Line():
    def __init__(self):
        # Track line properties
        self.found = False
        
        # Track line polynomials
        self.poly = [] # current polynomial fit (pixel space)
        self.polyx = [] # current polynomial idx (pixel space)
        self.polyWorld = [] # current polynomial fit (world space)
        self.poly_avg = None # average polynomial fit (pixel space)
        self.polyx_avg = None # average polynomial idx (pixel space)
        self.polyWorld_avg = None # average polynomial fit (world space)
        self.polyDiff = np.array([0, 0, 0], dtype='float')
        
        # Track line indeces
        self.idx_X = None
        self.idx_Y = None
        
        # Line curvature
        self.curveRad = None
        
    def isFound(self):
        return self.found
    
    def update(self, poly, idx, polyWorld, idxX, idxY):
        # Parameters
        n_avg = 3
        
        # Set a polynomial difference if a past result exists
        if self.found:
            self_polyDiff = self.poly[-1] - poly
            
        # Handler for new polynomial
        if poly is not None:
            # Ignore new line of polynomial difference is too high
            if ((self.polyDiff[0] > 0.001) or (self.polyDiff[1] > 1) or (self.polyDiff[2] > 100)):
                self.remove()
            else:
                # Set polynomial flag and points
                self.found = True
                self.idx_X = idxX
                self.idx_Y = idxY

                # Update polynomial list
                self.poly.append(poly)
                self.polyWorld.append(polyWorld)
                self.polyx.append(idx)

                # Remove any excess list values (> n_avg)
                if len(self.poly) > n_avg:
                    self.poly.pop(0)
                if len(self.polyWorld) > n_avg:
                    self.polyWorld.pop(0)
                if len(self.polyx) > n_avg:
                    self.polyx.pop(0)
                
                # Average line polynomials according to list
                if len(self.poly) > 0:
                    self.poly_avg = np.average(self.poly, axis=0)
                if len(self.polyWorld) > 0:
                    self.polyWorld_avg = np.average(self.polyWorld, axis=0)
                if len(self.polyx) > 0:
                    self.polyx_avg = np.average(self.polyx, axis=0)
                    
                # Calculate line radius
                self.calcRad()
        else:
            self.remove()

    def remove(self):
        if len(self.poly) > 0:
            self.poly.pop(0)
        if len(self.polyWorld) > 0:
            self.polyWorld.pop(0)
        if len(self.polyx) > 0:
            self.polyx.pop(0)
        if len(self.polyx) == 0 or len(self.poly) == 0:
            self.found = False
            self.polyDiff = np.array([0, 0, 0], dtype='float')
    
    def calcRad(self, h=720):
        # Conversion: pix to world (based on unwarp src and dst points), meters per pixel (mpp)
        y_mpp = 30 / 720 # Default conversion
        x_mpp = 3.7 / 520 # World lane width is 3.7m wide
        
        # Calculate radius
        polyWorld = self.polyWorld_avg
        curveRad = ((1+ (2 * polyWorld[0] * h * y_mpp + polyWorld[1]) ** 2) ** 1.5) / np.absolute(2 * polyWorld[0])
        self.curveRad = curveRad

# %% [markdown]
# ### Helper Functions

# %%
def undistort(Frame):
    '''
    undistort image using camera calibration points
    input: raw image, objpoints, imgpoints
    output: undistorted image
    '''
    # Gather necessary Frame properties
    img = Frame.orig
    objpts = Frame.objpts
    imgpts = Frame.imgpts
    img_size = (img.shape[1], img.shape[0])
    # Camera calibration
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpts, imgpts, img_size, None, None)
    undst = cv2.undistort(img, mtx, dist, None, mtx)
    
    # Update Frame properties
    Frame.undst = undst
    
    
def unwarp(Frame):
    '''
    unwarps image using source and destination points
    input: undistorted image
    output: unwarped image, Minv
    '''
    # Gather necessary Frame properties
    undst = np.copy(Frame.undst)
    h, w = (undst.shape[0], undst.shape[1])
    # Store warp borders
    src = np.float32([[595, 450], # top left
                      [689, 450], # top right
                      [216, 719], # bottom left
                      [1111, 719]]) # bottom right
    dst = np.float32([[380, 0], # top left
                      [900, 0], # top right
                      [380, 720], # bottom left
                      [900, 720]]) # bottom right
    srcBorder = np.array([[src[0][0],src[0][1]],[src[1][0],src[1][1]], [src[3][0],src[3][1]],[src[2][0],src[2][1]]], np.int32)
    Frame.srcBorder = srcBorder
    dstBorder = np.array([[dst[0][0],dst[0][1]],[dst[1][0],dst[1][1]], [dst[3][0],src[3][1]],[dst[2][0],dst[2][1]]], np.int32)
    # Get and store transform parameters
    M = cv2.getPerspectiveTransform(src, dst)
    Minv = cv2.getPerspectiveTransform(dst, src)
    # Do the warp
    warp = cv2.warpPerspective(undst, M, (w, h), flags=cv2.INTER_LINEAR)
    
    # Update Frame properties
    Frame.dstBorder = dstBorder
    Frame.M = M
    Frame.Minv = Minv
    Frame.warp = warp
    
    
def rectify(Frame):
    '''
    utilizes the pipeline outlined above: (HLS[2] & LAB[0]) | (Sobel_abs & Sobel_mag & Sobel_dir)
    '''
    # Gather necessary Frame properties
    warp = cv2.cvtColor(Frame.warp, cv2.COLOR_BGR2RGB)
    gray = cv2.cvtColor(warp, cv2.COLOR_BGR2GRAY)
    # Set color binary threshold parameters
    colorThres_low = 150
    colorThres_high = 255
    # Set sobel binary threshold parameters
    linKernel = 3
    linThres_min = 15
    linThres_max = 255
    radKernel = 1
    radThres_min = 0.01
    radThres_max = 0.4
    
    # Color
    s_channel = cv2.cvtColor(warp, cv2.COLOR_RGB2HLS)[:,:,2] # HLS, Schannel
    l_channel = cv2.cvtColor(warp, cv2.COLOR_RGB2Lab)[:,:,0] # LAB, L channel

    # Sobel
    sobel_abs = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 1, 0)) # x direction
    sobel_abs = np.uint8(255 * sobel_abs / np.max(sobel_abs)) # equalize to [0,255]
    sobel_magx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=linKernel) # x direction
    sobel_magy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=linKernel) # y direction
    sobel_mag = np.sqrt(sobel_magx**2 + sobel_magy**2) # normalize across x and y
    sobel_mag = np.uint8(255 * sobel_mag / np.max(sobel_mag)) # equalize to [0,255]
    sobel_dirx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=radKernel)
    sobel_diry = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=radKernel)
    sobel_dir = np.arctan2(np.absolute(sobel_diry), np.absolute(sobel_dirx))

    # Combined Binaries
    color_binary = np.zeros_like(s_channel)
    color_binary[(s_channel > colorThres_low) & (l_channel > colorThres_low)] = 1
    sobel_binary = np.zeros_like(sobel_abs)
    sobel_binary[((sobel_abs > linThres_min) & (sobel_abs <= linThres_max)) &
                 ((sobel_mag > linThres_min) & (sobel_mag <= linThres_max)) &
                 ((sobel_dir > radThres_min) & (sobel_dir <= radThres_max))] = 1
    combined_binary = np.zeros_like(color_binary)
    combined_binary[(color_binary == 1) | (sobel_binary == 1)] = 1
    
    # Update Frame properties
    Frame.color_binary = color_binary
    Frame.sobel_binary = sobel_binary
    Frame.combined_binary = combined_binary
    
    
def laneFinder(Frame):
    '''
    performs sliding window search on rectified image to discover lane lines
    '''
    # Gather necessary Frame properties
    combin = np.copy(Frame.combined_binary)
    h, w = (combin.shape[0], combin.shape[1])
    h_midpt = h // 2
    w_midpt = w // 2

    # Conversion: pix to world (based on unwarp src and dst points), meters per pixel (mpp)
    y_mpp = 30 / 720 # Default conversion
    x_mpp = 3.7 / 520 # World lane width is 3.7m wide
    
    # Sliding window parameters
    n_windows = 9
    h_window = h//n_windows
    margin = 100
    minpx = 50 # Threshold to re-center rectangle position

    # Use a histogram to determine likeliest lane x positions
    hist = np.sum(combin[h_midpt:,:], axis=0) # Lower half of image
    
    # Initialize image of detected lanes
    bin_ch = np.zeros_like(combin)
    detect = np.dstack((bin_ch, bin_ch, bin_ch))
    
    # Set line variables
    lineLeft = Frame.lineLeft
    lineRight = Frame.lineRight
       
    # Initialize Left and Right lane line indices list
    L_idx = []
    R_idx = []

    # Set results as base of left and right lane lines
    L_xBase = np.argmax(hist[:w_midpt]) # Left lower quadrant of image
    R_xBase = np.argmax(hist[w_midpt:]) + w_midpt # Right lower quadrant of image

    # Gather points from rectified binary image to detect
    nz = combin.nonzero()
    nz_y = np.array(nz[0])
    nz_x = np.array(nz[1])
 
    # Perform sliding window search by updating rectangle locations
    L_xCurr = L_xBase # Track Left rectangle position
    R_xCurr = R_xBase # Track Right rectangle position
    for win in range(n_windows):
        # Left and Right rectangle positions
        win_yMin = h - h_window * (win + 1) # Top of rectangle, y position
        win_yMax = h - h_window * win # Bottom of rectangle, y position
        winL_xMin = L_xCurr - margin
        winL_xMax = L_xCurr + margin
        winR_xMin = R_xCurr - margin
        winR_xMax = R_xCurr + margin
        
        # Add rectangles to image of detected lanes
        cv2.rectangle(detect, (winL_xMin, win_yMin), (winL_xMax, win_yMax), (0, 255, 0), 2)
        cv2.rectangle(detect, (winR_xMin, win_yMin), (winR_xMax, win_yMax), (0, 255, 0), 2)
        
        # Identify points within rectangle boundaries
        L_idxTemp = ((nz_y >= win_yMin) & (nz_y < win_yMax) & 
                     (nz_x >= winL_xMin) & (nz_x < winL_xMax)).nonzero()[0]
        R_idxTemp = ((nz_y >= win_yMin) & (nz_y < win_yMax) &
                     (nz_x >= winR_xMin) & (nz_x < winR_xMax)).nonzero()[0]
        
        # Append points to Left and Right lane indices lists
        L_idx.append(L_idxTemp)
        R_idx.append(R_idxTemp)
        
        # If number of found points exceeds threshold, readjust position of next rectangle
        if len(L_idxTemp) > minpx:
            L_xCurr = np.int(np.mean(nz_x[L_idxTemp]))
        if len(R_idxTemp) > minpx:
            R_xCurr = np.int(np.mean(nz_x[R_idxTemp]))
    
    # Concatenate list of indices into array
    L_idx = np.concatenate(L_idx)
    R_idx = np.concatenate(R_idx)
    
    # Get Left and Right lane polynomial points
    L_x = nz_x[L_idx]
    L_y = nz_y[L_idx]
    R_x = nz_x[R_idx]
    R_y = nz_y[R_idx]
    
    # Fit a 2nd order polynomial to Left and Right lane points (pixel space)
    L_poly = np.polyfit(L_y, L_x, 2)
    R_poly = np.polyfit(R_y, R_x, 2)
    
    # Fit a 2nd order polynomial to Left and Right lane points (world space)
    L_polyWorld = np.polyfit(L_y * y_mpp, L_x * x_mpp, 2)
    R_polyWorld = np.polyfit(R_y * y_mpp, R_x * x_mpp, 2)
    
    # Generate Left and Right polynomial lines
    ploty = np.linspace(0, h - 1, h)
    leftx = L_poly[0]*ploty**2 + L_poly[1]*ploty + L_poly[2]
    rightx = R_poly[0]*ploty**2 + R_poly[1]*ploty + R_poly[2]
    
    # Add Left and Right lane lines (and indices) to image of detected lanes
    detect[nz_y[L_idx], nz_x[L_idx]] = [255, 0, 0] # left line points marked red
    detect[nz_y[R_idx], nz_x[R_idx]] = [0, 0, 255] # right line points marked blue
    detect = drawLine(detect, L_poly, (255, 255, 0), 5) # line marked yellow
    detect = drawLine(detect, R_poly, (255, 255, 0), 5) # line marked yellow
        
    # Update Frame properties
    lineLeft.update(L_poly, leftx, L_polyWorld, L_x, L_y)
    lineRight.update(R_poly, rightx, R_polyWorld, R_x, R_y)
    calcPos(Frame)
    Frame.hist = hist
    Frame.detected_lines = detect
    
    
def laneRefiner(Frame):
    '''
    Redefines Left and Right lane line polynomials
    '''
    # Gather necessary Frame properties
    combin = np.copy(Frame.combined_binary)
    h, w = combin.shape[0], combin.shape[1]
    
    # Conversion: pix to world (based on unwarp src and dst points), meters per pixel (mpp)
    y_mpp = 30 / 720 # Default conversion
    x_mpp = 3.7 / 520 # World lane width is 3.7m wide
    
    # Polynomial parameters
    margin = 50 # Pixel threshold away from polynomial fit
        
    # Initialize image of detected lanes
    bin_ch = np.zeros_like(combin)
    detect = np.dstack((bin_ch, bin_ch, bin_ch))
    bounds = np.zeros_like(detect)
    
    # Set line variables
    lineLeft = Frame.lineLeft
    lineRight = Frame.lineRight
    
    # Gather points from rectified binary image
    nz = combin.nonzero()
    nz_y = np.array(nz[0])
    nz_x = np.array(nz[1])
    
    # Find points within margin of Left and Right lane line polynomials
    L_poly = lineLeft.poly[-1]
    R_poly = lineRight.poly[-1]
    L_idx = ((nz_x > (L_poly[0]*nz_y**2 + L_poly[1]*nz_y + L_poly[2] - margin)) &
             (nz_x < (L_poly[0]*nz_y**2 + L_poly[1]*nz_y + L_poly[2] + margin)))
    R_idx = ((nz_x > (R_poly[0]*nz_y**2 + R_poly[1]*nz_y + R_poly[2] - margin)) &
             (nz_x < (R_poly[0]*nz_y**2 + R_poly[1]*nz_y + R_poly[2] + margin)))
    
    # Find the new Left and Right lane line points
    L_x = nz_x[L_idx]
    L_y = nz_y[L_idx]
    R_x = nz_x[R_idx]
    R_y = nz_y[R_idx]
    
    # Find the new 2nd order polynomials for the L and R lane line points
    L_poly = np.polyfit(L_y, L_x, 2)
    R_poly = np.polyfit(R_y, R_x, 2)
    
    # Find the new 2nd order polynomials for the L and R lane line points
    L_polyWorld = np.polyfit(L_y * y_mpp, L_x * x_mpp, 2)
    R_polyWorld = np.polyfit(R_y * y_mpp, R_x * x_mpp, 2)
    
    # Generate Left and Right polynomial lines
    ploty = np.linspace(0, h - 1, h)
    leftx = L_poly[0]*ploty**2 + L_poly[1]*ploty + L_poly[2]
    rightx = R_poly[0]*ploty**2 + R_poly[1]*ploty + R_poly[2]

    # Create left and right boundaries for Left and Right rectify region
    leftx_Min = np.array([np.transpose(np.vstack([leftx - margin, ploty]))])
    leftx_Max = np.array([np.flipud(np.transpose(np.vstack([leftx + margin, ploty])))])
    left_bound = np.hstack([leftx_Min, leftx_Max])
    rightx_Min = np.array([np.transpose(np.vstack([rightx - margin, ploty]))])
    rightx_Max = np.array([np.flipud(np.transpose(np.vstack([rightx + margin, ploty])))])
    right_bound = np.hstack([rightx_Min, rightx_Max])
    
    # Add L & R points, lines, and boundaries to image
    detect[nz_y[L_idx], nz_x[L_idx]] = [255, 0, 0] # left line points marked red
    detect[nz_y[R_idx], nz_x[R_idx]] = [0, 0, 255] # right line points marked blue
    cv2.fillPoly(bounds, np.int_([left_bound]), (0, 255, 0)) # boundary is green
    cv2.fillPoly(bounds, np.int_([right_bound]), (0, 255, 0))
    detect = cv2.addWeighted(detect, 1, bounds, 0.3, 0)
    detect = drawLine(detect, L_poly, (255, 255, 0), 5) # line marked yellow
    detect = drawLine(detect, R_poly, (255, 255, 0), 5) # line marked yellow
    
    # Update Frame properties
    lineLeft.update(L_poly, leftx, L_polyWorld, L_x, L_y)
    lineRight.update(R_poly, rightx, R_polyWorld, R_x, R_y)
    calcPos(Frame)
    Frame.detected_lines = detect
    
    
def calcPos(Frame):
    '''
    calculates vehicle position offset from lane center
    '''
    # Get Frame properties
    h, w,_ = Frame.orig.shape
    
    # Conversion: pix to world (based on unwarp src and dst points), meters per pixel (mpp)
    x_mpp = 3.7 / 520 # World lane width is 3.7m wide
    x_pos = w // 2 # Assume camera is on center of vehicle
 
    # Set line variables
    lineLeft = Frame.lineLeft
    lineRight = Frame.lineRight
    
    # Use lowest line positions to determine center of lane
    try:
        L_poly = lineLeft.poly[-1]
        R_poly = lineRight.poly[-1]
        laneLeft = L_poly[0]*h**2 + L_poly[1]*h + L_poly[2]
        laneRight = R_poly[0]*h**2 + R_poly[1]*h + R_poly[2]
        laneCenter = (laneLeft + laneRight) // 2
        lanePos = (x_pos - laneCenter) * x_mpp
        Frame.lanePos = lanePos
    except:
        print("[offset can't be found]")
    
    
def drawLine(img, poly, color, thk=5):
    '''
    draws a line of input color and poly onto an input image
    '''# Gather necessary image properties
    h = img.shape[0]
    
    # Return input if no polynomal exists
    if poly is None:
        return img
    
    # Get line points of polynomial
    ploty = np.linspace(0, h-1, h)
    plotx = poly[0]*ploty**2 + poly[1]*ploty + poly[2]
    idx = np.array(np.transpose(np.vstack([plotx, ploty])))
    
    # Plot line onto original image
    img_out = np.copy(img)
    cv2.polylines(img_out, np.int32([idx]), isClosed = False, color=color, thickness=thk)
    
    return img_out
    
    
def drawText(img, Frame):
    '''
    draws text of Frame properties onto input image
    '''# Gather necessary image and Frame properties
    h = img.shape[0]
    lineLeft = Frame.lineLeft
    lineRight = Frame.lineRight
    d_center = Frame.lanePos
    img_out = np.copy(img)
    
    # Identify curve radius
    rad = (lineLeft.curveRad + lineRight.curveRad) / 2

    # Identify position from center
    direction = ''
    if d_center < 0:
        direction = 'left'
    elif d_center > 0:
        direction = 'right'
    d_centerAbs = abs(d_center)
        
    # Print text on output image
    font = cv2.FONT_HERSHEY_TRIPLEX
    txt1 = 'Curve radius: ' + '{:04.1f}'.format(rad) + 'm'
    cv2.putText(img_out, txt1, (40, 70), font, 1.5, (200, 255, 155), 2, cv2.LINE_AA)
    txt2 = '{:04.3f}'.format(d_centerAbs) + 'm ' + direction + ' of center'
    cv2.putText(img_out, txt2, (40, 120), font, 1.5, (200, 255, 155), 2, cv2.LINE_AA)

    return img_out
    
    
def drawLane(Frame):
    '''
    draws lane onto real world view image
    '''
    # Gather necessary Frame properties
    undst = Frame.undst
    h, w = undst.shape[0], undst.shape[1]
    Minv = Frame.Minv
    lineLeft = Frame.lineLeft
    lineRight = Frame.lineRight
    
    # Initialize new image
    lane_warp = np.zeros_like(undst).astype(np.uint8)

    # Get a best fit polynomial for L & R lines
    L_poly = lineLeft.poly_avg
    R_poly = lineRight.poly_avg
    
    # Generate points for polynomials
    ploty = np.linspace(0, h-1, h)
    leftx = L_poly[0]*ploty**2 + L_poly[1]*ploty + L_poly[2]
    rightx = R_poly[0]*ploty**2 + R_poly[1]*ploty + R_poly[2]
    
    # Recast lane boundary points into format for cv2.fillPoly()
    leftIdx = np.array([np.transpose(np.vstack([leftx, ploty]))])
    rightIdx = np.array([np.flipud(np.transpose(np.vstack([rightx, ploty])))])
    idx = np.hstack([leftIdx, rightIdx])
    
    # Append lane boundaries to color_warped
    cv2.fillPoly(lane_warp, np.int_([idx]), (0, 255, 0))   
    lane_warpL = drawLine(lane_warp, L_poly, (255, 0, 0), 20)
    lane_warpLR = drawLine(lane_warpL, R_poly, (0, 0, 255), 20)

    # Warp back to original image space using inverse perspective matrix (Minv)
    unwarp = cv2.warpPerspective(lane_warpLR, Minv, (w, h))
    comb_unwarp = cv2.addWeighted(undst, 1, unwarp, 0.3, 0)
    
    # Combine the result with the original image
    final = drawText(comb_unwarp, Frame)

    # Update Frame properties
    Frame.final = final
    
    
def visualize(name, img):
    '''
    displays input image in window of input name
    '''
    cv2.namedWindow(name, cv2.WINDOW_NORMAL)
    cv2.imshow(name, img)
    cv2.waitKey(1)
    
    
def visCollage(Frame):
    # Choose images for each quadrant
    h = 720
    w = 1280
    Q1 = Frame.orig
    Q2 = 255 * cv2.cvtColor(Frame.combined_binary, cv2.COLOR_GRAY2RGB)
    Q3 = Frame.detected_lines
    Q4 = Frame.final
    
    zero_ch = np.zeros((2*h, 2*w)).astype(np.uint8)
    collage = np.dstack((zero_ch, zero_ch, zero_ch))
    collage[0:h, 0:w, :] = Q1[:,:]
    collage[0:h, w:2*w, :] = Q2[:,:]
    collage[h:2*h, w:2*w, :] = Q3[:,:]
    collage[h:2*h, 0:w, :] = Q4[:,:]

    plt.figure()
    plt.axis('off')
    plt.imshow(collage)
    Frame.collage = collage
    
    
def visPipe(Frame):
    f, axs = plt.subplots(1, 4, figsize=(20,10))
    axs[0].imshow(Frame.orig)
    axs[1].imshow(Frame.combined_binary, cmap='gray')
    axs[2].imshow(Frame.detected_lines)
    axs[3].imshow(Frame.final)
    
    
def processImage(img):
    Frame.orig = img
    undistort(Frame)
    unwarp(Frame)
    rectify(Frame)
    if (Frame.lineLeft.isFound() and Frame.lineRight.isFound()):
        laneRefiner(Frame)
    else:
        laneFinder(Frame)
    drawLane(Frame)
    visCollage(Frame)
    return Frame.collage

# %% [markdown]
# ### Initialization

# %%
frameActive = False

# %%
# Global parameter
if not frameActive:
    Frame = Frame()
    frameActive = True

# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objpts = np.zeros((6*9,3), np.float32)
objpts[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2) # x, y coordinates

# Arrays to store object points and image points from all the images
Frame.objpts = [] #3d points in real world space
Frame.imgpts = [] # 2d points in image plane

# Make a list of calibration images
images = glob.glob(path_calImages + '*.jpg')

# Search for corners
for idx, fname in enumerate(images):
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    #find corners
    ret, corners = cv2.findChessboardCorners(gray, (9,6), None)

    #If found, add object points, image points
    if ret == True:
        Frame.objpts.append(objpts)
        Frame.imgpts.append(corners)

        #Draw and display the corners
'''
        cv2.drawChessboardCorners(img, (9,6), corners, ret)
        cv2.imshow('img', img)
        cv2.waitKey(1)

cv2.destroyAllWindows()
'''
# Out:
# "\n        cv2.drawChessboardCorners(img, (9,6), corners, ret)\n        cv2.imshow('img', img)\n        cv2.waitKey(1)\n\ncv2.destroyAllWindows()\n"

# %% [markdown]
# ### Test on Image

# %%
test_images = glob.glob(path_imgIn + '*.jpg')
n_test_images = int(len(test_images))

for i in range(n_test_images):
    Frame.reset()

    #test_image = cv2.imread(test_images[np.random.randint(n_test_images)])
    test_image = cv2.imread(test_images[i])
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    processed_image = processImage(test_image)
    image_out = cv2.cvtColor(processed_image, cv2.COLOR_RGB2BGR)

    cv2.imwrite(path_imgOut + 'fig_collage_' + str(i) + '.png', image_out)

# %% [markdown]
# ### Test on Video

# %%
#Video
output_file = path_vidOut + 'project_videoProcessed.mp4'
input_file = VideoFileClip(path_vidIn + 'project_video.mp4')
processedClip = input_file.fl_image(processImage)
#processedClip.write_videofile(processedClip, audio = False)
# %time processedClip.write_videofile(output_file, audio=False)
# Out:
# [MoviePy] >>>> Building video output_videos/project_videoProcessed.mp4
# [MoviePy] Writing video output_videos/project_videoProcessed.mp4
#  71%|███████   | 898/1261 [21:24<09:57,  1.65s/it]
